# %%
import watson_nlp

# %%
#Define Swedish text. To play around with sentiment score we advice you to choose a mix sentiment in that text

sv_text= "Jag orkar inte med leveransen! Ni lovade att allt kommer vara framme inom 3-5 dagar. \
Men jag fick paketet på måndag och det tog 2 veckor! Dock så älskar jag Jocos shampoo och balsam och tycker att de absolut är värda dessa 500 SEK"

# %%
# Load Syntax for Swedish language
syntax_model = watson_nlp.load(watson_nlp.download('syntax_izumo_sv_stock'))

# Detect tokens, lemma and part-of-speech
syntax_prediction = syntax_model.run(sv_text, parsers=('token', 'lemma', 'part_of_speech'))

# Print the syntax result
print(syntax_prediction)
# Out:
# {
#   "text": "Jag orkar inte med leveransen! Ni lovade att allt kommer vara framme inom 3-5 dagar. Men jag fick paketet på måndag och det tog 2 veckor! Dock så älskar jag Jocos shampoo och balsam och tycker att de absolut är värda dessa 500 SEK",
#   "producer_id": {
#     "name": "Izumo Text Processing",
#     "version": "0.0.1"
#   },
#   "tokens": [
#     {
#       "span": {
#         "begin": 0,
#         "end": 3,
#         "text": "Jag"
#       },
#       "lemma": "jag",
#       "part_of_speech": "POS_PRON",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 4,
#         "end": 9,
#         "text": "orkar"
#       },
#       "lemma": "orka",
#       "part_of_speech": "POS_VERB",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 10,
#         "end": 14,
#         "text": "inte"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_PART",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 15,
#         "end": 18,
#         "text": "med"
#       },
#       "lemma": "med",
#       "part_of_speech": "POS_ADP",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 19,
#         "end": 29,
#         "text": "leveransen"
#       },
#       "lemma": "leverans",
#       "part_of_speech": "POS_NOUN",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 29,
#         "end": 30,
#         "text": "!"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_PUNCT",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 31,
#         "end": 33,
#         "text": "Ni"
#       },
#       "lemma": "ni",
#       "part_of_speech": "POS_PRON",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 34,
#         "end": 40,
#         "text": "lovade"
#       },
#       "lemma": "lova",
#       "part_of_speech": "POS_VERB",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 41,
#         "end": 44,
#         "text": "att"
#       },
#       "lemma": "att",
#       "part_of_speech": "POS_SCONJ",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 45,
#         "end": 49,
#         "text": "allt"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_PRON",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 50,
#         "end": 56,
#         "text": "kommer"
#       },
#       "lemma": "komma",
#       "part_of_speech": "POS_AUX",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 57,
#         "end": 61,
#         "text": "vara"
#       },
#       "lemma": "vara",
#       "part_of_speech": "POS_AUX",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 62,
#         "end": 68,
#         "text": "framme"
#       },
#       "lemma": "framme",
#       "part_of_speech": "POS_ADV",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 69,
#         "end": 73,
#         "text": "inom"
#       },
#       "lemma": "inom",
#       "part_of_speech": "POS_ADP",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 74,
#         "end": 75,
#         "text": "3"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_NUM",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 75,
#         "end": 76,
#         "text": "-"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_SYM",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 76,
#         "end": 77,
#         "text": "5"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_NUM",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 78,
#         "end": 83,
#         "text": "dagar"
#       },
#       "lemma": "dag",
#       "part_of_speech": "POS_NOUN",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 83,
#         "end": 84,
#         "text": "."
#       },
#       "lemma": "",
#       "part_of_speech": "POS_PUNCT",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 85,
#         "end": 88,
#         "text": "Men"
#       },
#       "lemma": "men",
#       "part_of_speech": "POS_CCONJ",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 89,
#         "end": 92,
#         "text": "jag"
#       },
#       "lemma": "jag",
#       "part_of_speech": "POS_PRON",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 93,
#         "end": 97,
#         "text": "fick"
#       },
#       "lemma": "få",
#       "part_of_speech": "POS_VERB",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 98,
#         "end": 105,
#         "text": "paketet"
#       },
#       "lemma": "paket",
#       "part_of_speech": "POS_NOUN",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 106,
#         "end": 108,
#         "text": "på"
#       },
#       "lemma": "på",
#       "part_of_speech": "POS_ADP",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 109,
#         "end": 115,
#         "text": "måndag"
#       },
#       "lemma": "måndag",
#       "part_of_speech": "POS_NOUN",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 116,
#         "end": 119,
#         "text": "och"
#       },
#       "lemma": "och",
#       "part_of_speech": "POS_CCONJ",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 120,
#         "end": 123,
#         "text": "det"
#       },
#       "lemma": "den",
#       "part_of_speech": "POS_PRON",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 124,
#         "end": 127,
#         "text": "tog"
#       },
#       "lemma": "ta",
#       "part_of_speech": "POS_VERB",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 128,
#         "end": 129,
#         "text": "2"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_NUM",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 130,
#         "end": 136,
#         "text": "veckor"
#       },
#       "lemma": "vecka",
#       "part_of_speech": "POS_NOUN",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 136,
#         "end": 137,
#         "text": "!"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_PUNCT",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 138,
#         "end": 142,
#         "text": "Dock"
#       },
#       "lemma": "dock",
#       "part_of_speech": "POS_ADV",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 143,
#         "end": 145,
#         "text": "så"
#       },
#       "lemma": "så",
#       "part_of_speech": "POS_ADV",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 146,
#         "end": 152,
#         "text": "älskar"
#       },
#       "lemma": "älska",
#       "part_of_speech": "POS_VERB",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 153,
#         "end": 156,
#         "text": "jag"
#       },
#       "lemma": "jag",
#       "part_of_speech": "POS_PRON",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 157,
#         "end": 162,
#         "text": "Jocos"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_PROPN",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 163,
#         "end": 170,
#         "text": "shampoo"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_NOUN",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 171,
#         "end": 174,
#         "text": "och"
#       },
#       "lemma": "och",
#       "part_of_speech": "POS_CCONJ",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 175,
#         "end": 181,
#         "text": "balsam"
#       },
#       "lemma": "balsam",
#       "part_of_speech": "POS_NOUN",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 182,
#         "end": 185,
#         "text": "och"
#       },
#       "lemma": "och",
#       "part_of_speech": "POS_CCONJ",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 186,
#         "end": 192,
#         "text": "tycker"
#       },
#       "lemma": "tycka",
#       "part_of_speech": "POS_VERB",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 193,
#         "end": 196,
#         "text": "att"
#       },
#       "lemma": "att",
#       "part_of_speech": "POS_SCONJ",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 197,
#         "end": 199,
#         "text": "de"
#       },
#       "lemma": "den",
#       "part_of_speech": "POS_PRON",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 200,
#         "end": 207,
#         "text": "absolut"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_ADV",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 208,
#         "end": 210,
#         "text": "är"
#       },
#       "lemma": "vara",
#       "part_of_speech": "POS_AUX",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 211,
#         "end": 216,
#         "text": "värda"
#       },
#       "lemma": "värd",
#       "part_of_speech": "POS_ADJ",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 217,
#         "end": 222,
#         "text": "dessa"
#       },
#       "lemma": "denna",
#       "part_of_speech": "POS_DET",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 223,
#         "end": 226,
#         "text": "500"
#       },
#       "lemma": "",
#       "part_of_speech": "POS_NUM",
#       "dependency": null,
#       "features": []
#     },
#     {
#       "span": {
#         "begin": 227,
#         "end": 230,
#         "text": "SEK"
#       },
#       "lemma": "sek",
#       "part_of_speech": "POS_NOUN",
#       "dependency": null,
#       "features": []
#     }
#   ],
#   "sentences": [
#     {
#       "span": {
#         "begin": 0,
#         "end": 30,
#         "text": "Jag orkar inte med leveransen!"
#       }
#     },
#     {
#       "span": {
#         "begin": 31,
#         "end": 84,
#         "text": "Ni lovade att allt kommer vara framme inom 3-5 dagar."
#       }
#     },
#     {
#       "span": {
#         "begin": 85,
#         "end": 137,
#         "text": "Men jag fick paketet på måndag och det tog 2 veckor!"
#       }
#     },
#     {
#       "span": {
#         "begin": 138,
#         "end": 230,
#         "text": "Dock så älskar jag Jocos shampoo och balsam och tycker att de absolut är värda dessa 500 SEK"
#       }
#     }
#   ],
#   "paragraphs": [
#     {
#       "span": {
#         "begin": 0,
#         "end": 230,
#         "text": "Jag orkar inte med leveransen! Ni lovade att allt kommer vara framme inom 3-5 dagar. Men jag fick paketet på måndag och det tog 2 veckor! Dock så älskar jag Jocos shampoo och balsam och tycker att de absolut är värda dessa 500 SEK"
#       }
#     }
#   ]
# }

# %%
#Load Sentiment multi-lingual model 
sentiment_model = watson_nlp.load(watson_nlp.download('sentiment_sentence-bert_multi_stock'))

# %%
#Let's see the score for every sentence
sentiment_result = sentiment_model.run_batch(syntax_prediction.get_sentence_texts(), syntax_prediction.sentences)
print(sentiment_result)
# Out:
# [{
#   "score": -0.9243259226759545,
#   "label": "SENT_NEGATIVE",
#   "sentiment_mention": {
#     "span": {
#       "begin": 0,
#       "end": 30,
#       "text": "Jag orkar inte med leveransen!"
#     },
#     "sentimentprob": {
#       "positive": 0.003416604595258832,
#       "neutral": 0.12722082436084747,
#       "negative": 0.8693625330924988
#     }
#   },
#   "producer_id": {
#     "name": "Sentence Sentiment Bert Processing",
#     "version": "0.1.0"
#   }
# }, {
#   "score": 0.0,
#   "label": "SENT_NEUTRAL",
#   "sentiment_mention": {
#     "span": {
#       "begin": 31,
#       "end": 84,
#       "text": "Ni lovade att allt kommer vara framme inom 3-5 dagar."
#     },
#     "sentimentprob": {
#       "positive": 0.1314348578453064,
#       "neutral": 0.49505195021629333,
#       "negative": 0.37351325154304504
#     }
#   },
#   "producer_id": {
#     "name": "Sentence Sentiment Bert Processing",
#     "version": "0.1.0"
#   }
# }, {
#   "score": 0.0,
#   "label": "SENT_NEUTRAL",
#   "sentiment_mention": {
#     "span": {
#       "begin": 85,
#       "end": 137,
#       "text": "Men jag fick paketet på måndag och det tog 2 veckor!"
#     },
#     "sentimentprob": {
#       "positive": 0.005606655031442642,
#       "neutral": 0.7228087782859802,
#       "negative": 0.2715846300125122
#     }
#   },
#   "producer_id": {
#     "name": "Sentence Sentiment Bert Processing",
#     "version": "0.1.0"
#   }
# }, {
#   "score": 0.9845681273965534,
#   "label": "SENT_POSITIVE",
#   "sentiment_mention": {
#     "span": {
#       "begin": 138,
#       "end": 230,
#       "text": "Dock så älskar jag Jocos shampoo och balsam och tycker att de absolut är värda dessa 500 SEK"
#     },
#     "sentimentprob": {
#       "positive": 0.970772385597229,
#       "neutral": 0.028082983568310738,
#       "negative": 0.001144703128375113
#     }
#   },
#   "producer_id": {
#     "name": "Sentence Sentiment Bert Processing",
#     "version": "0.1.0"
#   }
# }]

# %%
#Let's see the score for the whole comment left by our customer
from watson_nlp.toolkit import predict_document_sentiment
document_sentiment = predict_document_sentiment(sentiment_result, sentiment_model.class_idxs)
print(document_sentiment)
# Out:
# {
#   "score": 0.356899,
#   "label": "SENT_POSITIVE",
#   "mixed": true,
#   "sentiment_mentions": [
#     {
#       "span": {
#         "begin": 0,
#         "end": 30,
#         "text": "Jag orkar inte med leveransen!"
#       },
#       "sentimentprob": {
#         "positive": 0.003416604595258832,
#         "neutral": 0.12722082436084747,
#         "negative": 0.8693625330924988
#       }
#     },
#     {
#       "span": {
#         "begin": 31,
#         "end": 84,
#         "text": "Ni lovade att allt kommer vara framme inom 3-5 dagar."
#       },
#       "sentimentprob": {
#         "positive": 0.1314348578453064,
#         "neutral": 0.49505195021629333,
#         "negative": 0.37351325154304504
#       }
#     },
#     {
#       "span": {
#         "begin": 85,
#         "end": 137,
#         "text": "Men jag fick paketet på måndag och det tog 2 veckor!"
#       },
#       "sentimentprob": {
#         "positive": 0.005606655031442642,
#         "neutral": 0.7228087782859802,
#         "negative": 0.2715846300125122
#       }
#     },
#     {
#       "span": {
#         "begin": 138,
#         "end": 230,
#         "text": "Dock så älskar jag Jocos shampoo och balsam och tycker att de absolut är värda dessa 500 SEK"
#       },
#       "sentimentprob": {
#         "positive": 0.970772385597229,
#         "neutral": 0.028082983568310738,
#         "negative": 0.001144703128375113
#       }
#     }
#   ]
# }

# %%
#Entity 
bert_entity_model = watson_nlp.load(watson_nlp.download('entity-mentions_bert_multi_stock'))

# %%
# Run the entity mention model on the result of syntax model
bert_entity_mentions = bert_entity_model.run(syntax_prediction)
print(bert_entity_mentions)
# Out:
# {
#   "mentions": [
#     {
#       "span": {
#         "begin": 74,
#         "end": 83,
#         "text": "3-5 dagar"
#       },
#       "type": "Duration",
#       "producer_id": {
#         "name": "BERT Entity Mentions",
#         "version": "0.0.1"
#       },
#       "confidence": 0.9528643488883972,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 109,
#         "end": 115,
#         "text": "måndag"
#       },
#       "type": "Date",
#       "producer_id": {
#         "name": "BERT Entity Mentions",
#         "version": "0.0.1"
#       },
#       "confidence": 0.8282042741775513,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 128,
#         "end": 136,
#         "text": "2 veckor"
#       },
#       "type": "Duration",
#       "producer_id": {
#         "name": "BERT Entity Mentions",
#         "version": "0.0.1"
#       },
#       "confidence": 0.9933708906173706,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 157,
#         "end": 162,
#         "text": "Jocos"
#       },
#       "type": "Organization",
#       "producer_id": {
#         "name": "BERT Entity Mentions",
#         "version": "0.0.1"
#       },
#       "confidence": 0.7914963960647583,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     },
#     {
#       "span": {
#         "begin": 223,
#         "end": 230,
#         "text": "500 SEK"
#       },
#       "type": "Money",
#       "producer_id": {
#         "name": "BERT Entity Mentions",
#         "version": "0.0.1"
#       },
#       "confidence": 0.9616751670837402,
#       "mention_type": "MENTT_UNSET",
#       "mention_class": "MENTC_UNSET",
#       "role": ""
#     }
#   ],
#   "producer_id": {
#     "name": "BERT Entity Mentions",
#     "version": "0.0.1"
#   }
# }

# %%
#Keywords Analysis
